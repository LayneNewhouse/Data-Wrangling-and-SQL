# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.cElementTree as ET
from pprint import pprint

OSMFILE = 'toronto_canada.osm'
tag_tags = []

def count_tags(filename):
        tags = {}
        tag = []
        for event, elem in ET.iterparse(filename):
            tag.append(elem.tag)
        for i in tag:
            if i in tags:
                tags[i] += 1
            else:
                tags[i] = 1         
        return tags

def test():
    tags = count_tags(OSMFILE)
    pprint(tags)
    tag_tags.append(tags['tag'])
   

if __name__ == "__main__":
    test()

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import re
import operator
from pprint import pprint

OSMFILE = 'toronto_canada.osm'

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
lower_2colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
omit_keys = []

def key_type(element, keys, other, problem_characters):
    if element.tag == "tag":
        k = element.get("k")
        if re.search(lower,k):
            keys['lower'] += 1
        elif re.search(lower_colon,k):
            keys['lower_colon'] += 1
        elif re.search(lower_2colon,k):
            keys['lower_2colon'] += 1
        elif re.search(problemchars,k):
            keys['problemchars'] += 1
            if k in problem_characters:
                problem_characters[k] += 1
            else:
                problem_characters[k] = 1
        else:
            keys['other'] += 1
            if k in other:
                other[k] += 1
            else:
                other[k] = 1
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "lower_2colon": 0, "problemchars": 0, "other": 0}
    other = {}
    problem_characters = {}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys, other, problem_characters)
    sort_other = sorted(other.items(), key=operator.itemgetter(1), reverse=True)
    sort_problem_characters = sorted(problem_characters.items(), 
                                     key=operator.itemgetter(1), reverse=True)
    #The two print statements below will display problem tags and problem characters
    #as well as the amount of times that these tag appears
    #print "OTHER:", sort_other
    #print "OTHER:", sort_problem_characters
    
    gct_count = 0
    
    for key in other:
        omit_keys.append(key)
        if 'geobase' in key or 'canvec' in key or 'tiger' in key:
            #print key, other[key]
            gct_count += other[key]
    for key in problem_characters:
        omit_keys.append(key)
        
    unique_not_gct = 0 
    for i in omit_keys:
        if 'geobase' not in i and 'canvec' not in i and 'tiger' not in i:
            unique_not_gct += 1
            #print i
    
    print                                                                                
    print "Problem tags make up %f%% of the total %d tags in the 'Toronto Canada' dataset" % (100*float(keys['other'])/tag_tags[0], 
                                                                                               tag_tags[0])
    print "%d out of the %d problem tags (%d%%) come from geobase, canvec and tiger tags" % (gct_count, keys['other'], 
                                                                                             100*float(gct_count)/keys['other'])
    print "i.e. 'geobase:acquisitionTechnique', 'canvec:UUID', 'tiger:name_base_1'"
    print "The remaining %d (%f%%) tags can either be changed by hand or ignored;" % (keys['other']-gct_count, 
                                                                                    (keys['other']-gct_count)/float(tag_tags[0]))
    print"of the remaining problem tags %d are unique." % unique_not_gct
    print
    #The print statment below will show all tags that are being omitted from this dataset
    #print omit_keys
    return keys



def test():
    keys = process_map(OSMFILE)
    pprint(keys)


if __name__ == "__main__":
    test()

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
from pprint import pprint

OSMFILE = "toronto_canada.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
updated_street_names = {}

# Values following "Commons" were added after running against the Toronto dataset
# Compared to https://en.wikipedia.org/wiki/Street_suffix
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Crescent", "Line", "Circle", "Gardens", "Close", "Concession",
            "Gate", "Grove", "Heights", "Hill", "Path", "Run", "Sideroad", "Terrace", "Way", "Townline",
            "North", "East", "South", "West"]
# Names ending with North, East, South, West 
# 'Highway  5  West' => 'Highway 5 West' 
# 'Sideroad 5 Tosorontio' => 'Tosorontio Sideroad 5'


# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "street": "Street",
            "STREET": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "avenue": "Avenue",
            "Rd": "Road",
            "Rd.": "Road",
            "road": "Road",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Fernway": "Fern Way",
            "By-pass": "Bypass",
            "Cir": "Circle",
            "Cres": "Crescent",
            "Cresent": "Crescent",
            #"Crest": "Crescent", -> Individual cases...
            "Crt": "Court",
            "Ct": "Court",
            "Cv": "Court",
            "Dr": "Drive",
            "Driver": "Drive",
            "E": "East",
            "E.": "East",
            "Hrbr": "Harbour Way",
            "Lan": "Lane",
            "Lanes": "Lane",
            "Ldg": "Landing",
            "N": "North",
            "S": "South",
            "S.": "South",
            "Trl": "Trail",
            "W": "West",
            "W.": "West",
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    #re.sub(pattern, repl, string, count=0, flags=0)
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            if street_type in mapping:
                name = re.sub(street_type, mapping[street_type], name)
    return name


def test():
    st_types = audit(OSMFILE)
    print "The dataset contains %d street type tags" % len(st_types)
    #pprint(dict(st_types))
    
    count = 0
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            if better_name != name:
                # The print statment below shows all street names that were altered
                #print name, "=>", better_name
                count += 1
                updated_street_names[name] = better_name
    print "of these, %d tags were updated for constistancy" % count
    # the variable updated_street_names contains a dictionary using the old names as the key 
    # and the updated names as the values
    #print updated_street_names


if __name__ == '__main__':
    test()

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import csv
import codecs
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

OSM_PATH = "toronto_canada.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "node_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "way_nodes.csv"
WAY_TAGS_PATH = "way_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
    if element.tag == 'node':
        for field in NODE_FIELDS:
            node_attribs[field] = element.attrib[field]
        for tag in element.iter("tag"):    
            tags = create_tag_dict(element, tag, tags, default_tag_type)
        #print {'node': node_attribs, 'node_tags': tags} ...debugging
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        for field in WAY_FIELDS:
            way_attribs[field] = element.attrib[field]
        
        position = 0
        for node in element.iter("nd"):
            node_dict = {'id': element.attrib['id'], 'node_id': node.attrib['ref'], 'position': position}
            position += 1
            way_nodes.append(node_dict)
            
        for tag in element.iter("tag"):    
            tags = create_tag_dict(element, tag, tags, default_tag_type)
        #print {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}    
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

def create_tag_dict(element, tag, tags, tag_type):
    k = tag.attrib['k']
    if not re.search(PROBLEMCHARS, k):
        # The following three lines omit problem keys found earlier as well as update
        # old street names with the improved street names from the previous script
        if k not in omit_keys:
            if k in updated_street_names:
                k = updated_street_names[k]
            tag_dict = {}
            tag_dict['id'] = element.attrib['id']
            if ":" not in k:
                tag_dict['key'] = k
            else:
                tag_type = tag.attrib['k'].split(':',1)[0]
                k = tag.attrib['k'].split(':',1)[1]
                tag_dict['key'] = k
            tag_dict['value'] = tag.attrib['v']
            tag_dict['type'] = tag_type
            tags.append(tag_dict)
    return tags

        

# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as node_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(node_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=False)

# %%
import sqlite3
import csv
from pprint import pprint

nodes_csv = 'nodes.csv'
node_tags_csv = 'node_tags.csv'
ways_csv = 'ways.csv'
way_tags_csv = 'way_tags.csv'
way_nodes_csv = 'way_nodes.csv'


# Connect to the database, if it doesn't exist it will be created
sqlite_file = 'toronto_canada.db'
db = sqlite3.connect(sqlite_file)
db.text_factory = str

# Create a cursor object
c = db.cursor()

# Create the tables
c.execute('''
CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT)
''')
c.execute('''
CREATE TABLE node_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id))
''')
c.execute('''
CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT)
''')
c.execute('''
CREATE TABLE way_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id))
''')
c.execute('''
CREATE TABLE way_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id))    
''')

# Commit changes
db.commit()

# Read in the data
with open(nodes_csv, 'rb') as read_csv:
    reader = csv.DictReader(read_csv) #comma is default delimiter
    nodes_db = [(i['id'], i['lat'], i['lon'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in reader]
with open(node_tags_csv, 'rb') as read_csv:
    reader = csv.DictReader(read_csv) #comma is default delimiter
    node_tags_db = [(i['id'], i['key'], i['value'], i['type']) for i in reader]
with open(ways_csv, 'rb') as read_csv:
    reader = csv.DictReader(read_csv) #comma is default delimiter
    ways_db = [(i['id'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in reader]
with open(way_tags_csv, 'rb') as read_csv:
    reader = csv.DictReader(read_csv) #comma is default delimiter
    way_tags_db = [(i['id'], i['key'], i['value'], i['type']) for i in reader]
with open(way_nodes_csv, 'rb') as read_csv:
    reader = csv.DictReader(read_csv) #comma is default delimiter
    way_nodes_db = [(i['id'], i['node_id'], i['position']) for i in reader]
    
    
# Insert formatted data
c.executemany('''
    INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) 
    VALUES (?, ?, ?, ?, ?, ?, ?, ?);''', nodes_db)
c.executemany('''
    INSERT INTO node_tags(id, key, value, type) 
    VALUES (?, ?, ?, ?);''', node_tags_db)
c.executemany('''
    INSERT INTO ways(id, user, uid, version, changeset, timestamp) 
    VALUES (?, ?, ?, ?, ?, ?);''', ways_db)
c.executemany('''
    INSERT INTO way_tags(id, key, value, type) 
    VALUES (?, ?, ?, ?);''', way_tags_db)
c.executemany('''
    INSERT INTO way_nodes(id, node_id, position) 
    VALUES (?, ?, ?);''', way_nodes_db)
db.commit()

# Check that the data is imported correctly
#c.execute ('SELECT * FROM nodes')
#all_rows = c.fetchall()
#print('1):')
#pprint(all_rows)

db.close()

# %%
#TEMP
import sqlite3
from pprint import pprint
sqlite_file = 'toronto_canada.db'

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
#c.execute ('SELECT user, COUNT(*) FROM nodes GROUP BY user ORDER BY COUNT(*) DESC')
#c.execute ('SELECT user, COUNT(*) FROM ways GROUP BY user ORDER BY COUNT(*) DESC')
#c.execute ('SELECT * FROM way_nodes')
all_rows = c.fetchall()
pprint(all_rows)
db.close()

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
#c.execute ('SELECT * FROM way_nodes')
c.execute ('PRAGMA PAGE_SIZE')
page_size = c.fetchall()
c.execute ('PRAGMA PAGE_COUNT')
page_count = c.fetchall()
db.close()
#print page_size, page_count
# Page size shows the size of the pages in bytes
# Page count shows the amount of pages that are allocated to the database
page_size = page_size[0][0]
page_count = page_count[0][0]
print "The size of this database is %d kB" % (page_size*page_count/1024)

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT COUNT(DISTINCT uid)
    FROM nodes
''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(1741,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT COUNT(DISTINCT uid)
    FROM (SELECT uid FROM nodes
    UNION SELECT uid FROM ways)
''')
all_rows = c.fetchall()
#pprint(all_rows)
db.close()
unique_uid = all_rows[0][0]
print "%d unique users have contributed to the node and way tags for this database" % unique_uid
# Out:
# 1985 unique users have contributed to the node and way tags for this database

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT count(id) FROM nodes
''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(4873350,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT count(id) FROM ways
''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(710944,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT *
    FROM (SELECT count(id) FROM ways
    UNION SELECT count(id) FROM nodes)
''')
idWaysNodes = c.fetchall()
c.execute ('''
    SELECT COUNT(id)
    FROM (SELECT id FROM ways
    UNION SELECT id FROM nodes)
''')
idUnique = c.fetchall()
db.close()
# changing the order in which ways and nodes appear in the union 
# does not seem to change the order of the final table
print "There are %d node tags and %d way tags combining to a total of %d way/node tags." % (idWaysNodes[1][0], idWaysNodes[0][0], 
                                                                                            idWaysNodes[1][0] + idWaysNodes[0][0])
print "Of these tags, %d are not unique between the nodes and the ways tables." % (idWaysNodes[1][0] + idWaysNodes[0][0]
                                                                                   - idUnique[0][0])
# Out:
# There are 4873350 node tags and 710944 way tags combining to a total of 5584294 way/node tags.
# Of these tags, 506 are not unique between the nodes and the ways tables.

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Verify the number of non-unique id's between the nodes and ways tables.
c.execute ('''
    SELECT COUNT(id)
    FROM nodes,
    (SELECT id as wayid FROM ways) as subq
    WHERE nodes.id = wayid
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(506,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# sample of common way and node tags
c.execute ('''
    SELECT id
    FROM nodes,
    (SELECT id as wayid FROM ways) as subq
    WHERE nodes.id = wayid
    LIMIT 1
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(21428979,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT id, lat, lon, user, uid, version, changeset, timestamp
    FROM nodes
    WHERE id = '21428979'
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(21428979,
#   43.6131187,
#   -79.5521881,
#   u'permute',
#   158267,
#   12,
#   30030302,
#   u'2015-04-07T03:05:37Z')]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT id, user, uid, version, changeset, timestamp
    FROM ways
    WHERE id = '21428979'
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(21428979, u'andrewpmk', 1679, u'3', 20777634, u'2014-02-25T19:30:51Z')]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT type, COUNT(*)
    FROM node_tags
    GROUP BY type
    ORDER BY COUNT(*) DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'addr', 1463356),
#  (u'regular', 833650),
#  (u'opendata', 4109),
#  (u'payment', 1342),
#  (u'source', 1044),
#  (u'species', 941),
#  (u'genus', 931),
#  (u'colour', 799),
#  (u'name', 610),
#  (u'crossing', 601),
#  (u'fire_hydrant', 582),
#  (u'tower', 492),
#  (u'fuel', 358),
#  (u'contact', 337),
#  (u'traffic_signals', 318),
#  (u'gnis', 263),
#  (u'recycling', 220),
#  (u'generator', 154),
#  (u'works', 112),
#  (u'internet_access', 97),
#  (u'toilets', 81),
#  (u'diet', 64),
#  (u'cost', 63),
#  (u'wetap', 60),
#  (u'is_in', 57),
#  (u'atm', 35),
#  (u'healthcare', 34),
#  (u'seamark', 31),
#  (u'service', 30),
#  (u'wheelchair', 25),
#  (u'building', 23),
#  (u'survey', 22),
#  (u'storage', 19),
#  (u'lamp', 13),
#  (u'phone', 13),
#  (u'capacity', 12),
#  (u'maxspeed', 12),
#  (u'communication', 11),
#  (u'disused', 10),
#  (u'surveillance', 10),
#  (u'beacon', 9),
#  (u'camera', 9),
#  (u'destination', 8),
#  (u'railway', 6),
#  (u'currency', 5),
#  (u'light', 5),
#  (u'mast', 5),
#  (u'monitoring', 5),
#  (u'opening_hours', 5),
#  (u'dance', 4),
#  (u'exit_to', 4),
#  (u'restriction', 4),
#  (u'vandalized', 4),
#  (u'drink', 3),
#  (u'health_facility', 3),
#  (u'manufacturer', 3),
#  (u'maxheight', 3),
#  (u'social_facility', 3),
#  (u'weather', 3),
#  (u'census', 2),
#  (u'fee', 2),
#  (u'health', 2),
#  (u'note', 2),
#  (u'public_transport', 2),
#  (u'ref', 2),
#  (u'aerodrome', 1),
#  (u'amenity', 1),
#  (u'blood', 1),
#  (u'communications_transponder', 1),
#  (u'fishing_bait', 1),
#  (u'health_speciality', 1),
#  (u'language', 1),
#  (u'manager', 1),
#  (u'operator', 1),
#  (u'post_box', 1),
#  (u'reuse', 1),
#  (u'scuba_diving', 1),
#  (u'swing_gate', 1),
#  (u'temporary', 1),
#  (u'tesla', 1),
#  (u'theatre', 1),
#  (u'vehicle', 1)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT key, COUNT(*)
    FROM node_tags
    GROUP BY key
    ORDER BY COUNT(*) DESC
    LIMIT 20
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'source', 483041),
#  (u'street', 472140),
#  (u'housenumber', 472136),
#  (u'city', 414610),
#  (u'highway', 85423),
#  (u'country', 50682),
#  (u'name', 35732),
#  (u'state', 26598),
#  (u'amenity', 25980),
#  (u'province', 23890),
#  (u'created_by', 20635),
#  (u'crossing', 20245),
#  (u'operator', 17359),
#  (u'shop', 12181),
#  (u'natural', 11226),
#  (u'shelter', 10177),
#  (u'power', 8872),
#  (u'website', 7052),
#  (u'type', 7044),
#  (u'note', 5010)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Shows the most common keys within way_tags
c.execute ('''
    SELECT key, COUNT(*)
    FROM way_tags
    GROUP BY key
    ORDER BY COUNT(*) DESC
    LIMIT 10
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'source', 464856),
#  (u'highway', 242805),
#  (u'interpolation', 226512),
#  (u'surface', 161827),
#  (u'lanes', 150670),
#  (u'name', 145372),
#  (u'building', 102326),
#  (u'attribution', 87188),
#  (u'access', 59372),
#  (u'is_in', 49761)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT value, COUNT(*)
    FROM node_tags
    WHERE key = 'amenity'
    GROUP BY value
    ORDER BY COUNT(*) DESC
    LIMIT 10
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'fast_food', 2996),
#  (u'restaurant', 2744),
#  (u'bench', 2352),
#  (u'post_box', 1964),
#  (u'cafe', 1409),
#  (u'parking', 1233),
#  (u'waste_basket', 1171),
#  (u'bank', 1046),
#  (u'fuel', 1001),
#  (u'pharmacy', 743)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT value, COUNT(*)
    FROM way_tags
    WHERE key = 'amenity'
    GROUP BY value
    ORDER BY COUNT(*) DESC
    LIMIT 10
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'parking', 30252),
#  (u'school', 2340),
#  (u'place_of_worship', 1445),
#  (u'restaurant', 309),
#  (u'fast_food', 290),
#  (u'cafe', 226),
#  (u'bank', 207),
#  (u'car_wash', 130),
#  (u'community_centre', 127),
#  (u'fire_station', 117)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# what are the way id's that have only a single node
c.execute ('''
    SELECT id, node_id, position FROM 
    (SELECT id, node_id, position, COUNT(*) as nodeCount
    FROM way_nodes
    GROUP BY id)
    WHERE nodeCount = 1
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(4055112, 21488808, 0),
#  (5715385, 43007918, 0),
#  (5715901, 43013058, 0),
#  (5716071, 43014448, 0),
#  (5717530, 43026496, 0),
#  (5718641, 43044724, 0),
#  (5718776, 43046596, 0),
#  (5718892, 43033354, 0),
#  (8046513, 60169823, 0),
#  (13866550, 130161213, 0),
#  (23634848, 60226522, 0),
#  (24540440, 26307677, 0),
#  (25336264, 60169620, 0),
#  (27052915, 1236861279, 0),
#  (27209568, 298579089, 0),
#  (27238513, 298935188, 0),
#  (27238760, 298936587, 0),
#  (27238784, 298936377, 0),
#  (31513894, 31934822, 0),
#  (33931591, 388655609, 0),
#  (33932698, 388744304, 0),
#  (33933093, 388854128, 0),
#  (33933120, 388720583, 0),
#  (33933886, 388808456, 0),
#  (33939353, 388735979, 0),
#  (33940953, 388869618, 0),
#  (33944343, 388897093, 0),
#  (33947565, 388655609, 0),
#  (33949064, 388829216, 0),
#  (33949318, 388904235, 0),
#  (33949742, 388821332, 0),
#  (33950831, 388725017, 0),
#  (33952601, 388774538, 0),
#  (33957561, 388672393, 0),
#  (33961358, 388744304, 0),
#  (33961913, 388926463, 0),
#  (33963782, 388787143, 0),
#  (33965528, 388694030, 0),
#  (34191952, 392172075, 0),
#  (34192045, 1542726042, 0),
#  (34192129, 392172075, 0),
#  (35230643, 413223044, 0),
#  (35257537, 413229730, 0),
#  (35288577, 413624404, 0),
#  (35288872, 413644031, 0),
#  (35289017, 413615005, 0),
#  (35289147, 413623404, 0),
#  (35289376, 413625015, 0),
#  (35289573, 413644529, 0),
#  (35289846, 413612070, 0),
#  (35290205, 413642536, 0),
#  (313025866, 476222470, 0),
#  (320620027, 3272251427L, 0),
#  (320620033, 3272251433L, 0),
#  (320620052, 3272251579L, 0),
#  (320727878, 3273644852L, 0),
#  (324622586, 3313336785L, 0),
#  (374772033, 392178002, 0),
#  (392653500, 3958453190L, 0),
#  (396904412, 2005936786, 0),
#  (399682386, 4023850376L, 0),
#  (399686261, 4023876213L, 0),
#  (399711912, 4024093464L, 0),
#  (400040015, 4026710152L, 0),
#  (400040036, 4026710153L, 0),
#  (400271813, 4028614651L, 0),
#  (400271817, 4028614980L, 0),
#  (400271821, 4028614636L, 0),
#  (400271831, 4028616396L, 0),
#  (400272130, 4028615656L, 0),
#  (400272184, 4028616390L, 0),
#  (400272263, 4028615637L, 0),
#  (400272642, 4028614981L, 0),
#  (400295300, 4028778040L, 0),
#  (400295445, 4028777928L, 0),
#  (400295541, 4028777695L, 0),
#  (400620493, 2583141165L, 0),
#  (401240613, 4036768805L, 0),
#  (401240675, 4036768806L, 0),
#  (401244193, 4036799450L, 0),
#  (401245383, 4036815224L, 0),
#  (401252997, 4036873478L, 0),
#  (401253057, 4036873479L, 0),
#  (421679755, 4214369041L, 0),
#  (434825067, 4327453739L, 0),
#  (436827308, 2682074236L, 0),
#  (438001054, 4357716084L, 0)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT COUNT(*) FROM 
    (SELECT COUNT(*) as nodeCount
    FROM way_nodes
    GROUP BY id)
    WHERE nodeCount = 1
    ''')
all_rows = c.fetchall()
db.close()
print "%d ways have only a single node assigned to them" % all_rows[0][0]
# Out:
# 545 ways have only a single node assigned to them

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
#???
c.execute ('''
    SELECT key, COUNT(*)
    FROM (SELECT key FROM node_tags
    UNION SELECT key FROM way_tags)
    GROUP BY key
    ORDER BY COUNT(*) DESC
    LIMIT 20
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'abandoned', 1),
#  (u'abutters', 1),
#  (u'access', 1),
#  (u'accessible', 1),
#  (u'account_cards', 1),
#  (u'ad_screens', 1),
#  (u'addr', 1),
#  (u'address', 1),
#  (u'admin_level', 1),
#  (u'administrative', 1),
#  (u'advanced_green', 1),
#  (u'advertising', 1),
#  (u'advised', 1),
#  (u'advisory', 1),
#  (u'advisory_speed', 1),
#  (u'aerialway', 1),
#  (u'aerodrome', 1),
#  (u'aeroway', 1),
#  (u'after_hours_return', 1),
#  (u'air', 1)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Cafes
c.execute ('''
    SELECT id, value, key, type
    FROM node_tags
    WHERE value = 'cafe'
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(48553537, u'cafe', u'amenity', u'regular'),
#  (53542349, u'cafe', u'amenity', u'regular'),
#  (54965507, u'cafe', u'amenity', u'regular'),
#  (59566254, u'cafe', u'amenity', u'regular'),
#  (59566311, u'cafe', u'amenity', u'regular'),
#  (60930953, u'cafe', u'amenity', u'regular'),
#  (60930956, u'cafe', u'amenity', u'regular'),
#  (60931257, u'cafe', u'amenity', u'regular'),
#  (79877659, u'cafe', u'amenity', u'regular'),
#  (80927400, u'cafe', u'amenity', u'regular'),
#  (95378352, u'cafe', u'amenity', u'regular'),
#  (118421701, u'cafe', u'amenity', u'regular'),
#  (158701760, u'cafe', u'amenity', u'regular'),
#  (158707495, u'cafe', u'amenity', u'regular'),
#  (176544089, u'cafe', u'amenity', u'regular'),
#  (211287594, u'cafe', u'amenity', u'regular'),
#  (211290791, u'cafe', u'amenity', u'regular'),
#  (211313114, u'cafe', u'amenity', u'regular'),
#  (241263058, u'cafe', u'amenity', u'regular'),
#  (243421095, u'cafe', u'amenity', u'regular'),
#  (245020011, u'cafe', u'amenity', u'regular'),
#  (245020012, u'cafe', u'amenity', u'regular'),
#  (245020016, u'cafe', u'amenity', u'regular'),
#  (246694072, u'cafe', u'amenity', u'regular'),
#  (246694096, u'cafe', u'amenity', u'regular'),
#  (247134293, u'cafe', u'amenity', u'regular'),
#  (249298161, u'cafe', u'amenity', u'regular'),
#  (249298895, u'cafe', u'amenity', u'regular'),
#  (249989359, u'cafe', u'amenity', u'regular'),
#  (252170636, u'cafe', u'amenity', u'regular'),
#  (253433635, u'cafe', u'amenity', u'regular'),
#  (253718779, u'cafe', u'amenity', u'regular'),
#  (253818647, u'cafe', u'amenity', u'regular'),
#  (263109219, u'cafe', u'amenity', u'regular'),
#  (265007679, u'cafe', u'amenity', u'regular'),
#  (267314429, u'cafe', u'amenity', u'regular'),
#  (267316723, u'cafe', u'amenity', u'regular'),
#  (267597777, u'cafe', u'amenity', u'regular'),
#  (275466315, u'cafe', u'amenity', u'regular'),
#  (276474692, u'cafe', u'amenity', u'regular'),
#  (276476517, u'cafe', u'amenity', u'regular'),
#  (277040113, u'cafe', u'amenity', u'regular'),
#  (277141752, u'cafe', u'amenity', u'regular'),
#  (277706900, u'cafe', u'amenity', u'regular'),
#  (278103212, u'cafe', u'amenity', u'regular'),
#  (279641656, u'cafe', u'amenity', u'regular'),
#  (280492356, u'cafe', u'amenity', u'regular'),
#  (280493843, u'cafe', u'amenity', u'regular'),
#  (280495836, u'cafe', u'amenity', u'regular'),
#  (280495941, u'cafe', u'amenity', u'regular'),
#  (280496172, u'cafe', u'amenity', u'regular'),
#  (280889469, u'cafe', u'amenity', u'regular'),
#  (280901626, u'cafe', u'amenity', u'regular'),
#  (281361786, u'cafe', u'amenity', u'regular'),
#  (281658959, u'cafe', u'amenity', u'regular'),
#  (281660373, u'cafe', u'amenity', u'regular'),
#  (281664166, u'cafe', u'amenity', u'regular'),
#  (281664356, u'cafe', u'amenity', u'regular'),
#  (281665202, u'cafe', u'amenity', u'regular'),
#  (281668247, u'cafe', u'amenity', u'regular'),
#  (281669476, u'cafe', u'amenity', u'regular'),
#  (283527209, u'cafe', u'amenity', u'regular'),
#  (286375634, u'cafe', u'amenity', u'regular'),
#  (286375635, u'cafe', u'amenity', u'regular'),
#  (287145784, u'cafe', u'amenity', u'regular'),
#  (288057956, u'cafe', u'amenity', u'regular'),
#  (288058001, u'cafe', u'amenity', u'regular'),
#  (288059641, u'cafe', u'amenity', u'regular'),
#  (288064482, u'cafe', u'amenity', u'regular'),
#  (288065234, u'cafe', u'amenity', u'regular'),
#  (292756545, u'cafe', u'amenity', u'regular'),
#  (292779619, u'cafe', u'amenity', u'regular'),
#  (295319870, u'cafe', u'amenity', u'regular'),
#  (300469794, u'cafe', u'amenity', u'regular'),
#  (300469798, u'cafe', u'amenity', u'regular'),
#  (300475614, u'cafe', u'amenity', u'regular'),
#  (302045033, u'cafe', u'amenity', u'regular'),
#  (302045062, u'cafe', u'amenity', u'regular'),
#  (302416906, u'cafe', u'amenity', u'regular'),
#  (303251376, u'cafe', u'amenity', u'regular'),
#  (303251890, u'cafe', u'amenity', u'regular'),
#  (304899718, u'cafe', u'amenity', u'regular'),
#  (304899767, u'cafe', u'amenity', u'regular'),
#  (305027002, u'cafe', u'amenity', u'regular'),
#  (305489899, u'cafe', u'amenity', u'regular'),
#  (305490710, u'cafe', u'amenity', u'regular'),
#  (305490901, u'cafe', u'amenity', u'regular'),
#  (305766860, u'cafe', u'amenity', u'regular'),
#  (305767244, u'cafe', u'amenity', u'regular'),
#  (306328612, u'cafe', u'amenity', u'regular'),
#  (306328629, u'cafe', u'amenity', u'regular'),
#  (307781391, u'cafe', u'amenity', u'regular'),
#  (308447579, u'cafe', u'amenity', u'regular'),
#  (308697096, u'cafe', u'amenity', u'regular'),
#  (308808289, u'cafe', u'amenity', u'regular'),
#  (310142481, u'cafe', u'amenity', u'regular'),
#  (310957327, u'cafe', u'amenity', u'regular'),
#  (313440504, u'cafe', u'amenity', u'regular'),
#  (314935050, u'cafe', u'amenity', u'regular'),
#  (315645175, u'cafe', u'amenity', u'regular'),
#  (315646071, u'cafe', u'amenity', u'regular'),
#  (315662287, u'cafe', u'amenity', u'regular'),
#  (315662865, u'cafe', u'amenity', u'regular'),
#  (331078296, u'cafe', u'amenity', u'regular'),
#  (332338882, u'cafe', u'amenity', u'regular'),
#  (333553037, u'cafe', u'amenity', u'regular'),
#  (333553179, u'cafe', u'amenity', u'regular'),
#  (333553652, u'cafe', u'amenity', u'regular'),
#  (339423473, u'cafe', u'amenity', u'regular'),
#  (339551811, u'cafe', u'amenity', u'regular'),
#  (343270097, u'cafe', u'amenity', u'regular'),
#  (343273653, u'cafe', u'amenity', u'regular'),
#  (343275414, u'cafe', u'amenity', u'regular'),
#  (343275864, u'cafe', u'amenity', u'regular'),
#  (344473397, u'cafe', u'amenity', u'regular'),
#  (353394655, u'cafe', u'amenity', u'regular'),
#  (354973069, u'cafe', u'amenity', u'regular'),
#  (354974891, u'cafe', u'amenity', u'regular'),
#  (355047137, u'cafe', u'amenity', u'regular'),
#  (356321644, u'cafe', u'amenity', u'regular'),
#  (356321730, u'cafe', u'amenity', u'regular'),
#  (366654928, u'cafe', u'amenity', u'regular'),
#  (367757826, u'cafe', u'amenity', u'regular'),
#  (368122158, u'cafe', u'amenity', u'regular'),
#  (371377870, u'cafe', u'amenity', u'regular'),
#  (372344042, u'cafe', u'amenity', u'regular'),
#  (372387253, u'cafe', u'amenity', u'regular'),
#  (373114824, u'cafe', u'amenity', u'regular'),
#  (373153520, u'cafe', u'amenity', u'regular'),
#  (393536004, u'cafe', u'amenity', u'regular'),
#  (400705355, u'cafe', u'amenity', u'regular'),
#  (400710181, u'cafe', u'amenity', u'regular'),
#  (400914580, u'cafe', u'amenity', u'regular'),
#  (400917823, u'cafe', u'amenity', u'regular'),
#  (400943529, u'cafe', u'amenity', u'regular'),
#  (400971509, u'cafe', u'amenity', u'regular'),
#  (406897226, u'cafe', u'amenity', u'regular'),
#  (406920117, u'cafe', u'amenity', u'regular'),
#  (406932478, u'cafe', u'amenity', u'regular'),
#  (409158418, u'cafe', u'amenity', u'regular'),
#  (409179307, u'cafe', u'amenity', u'regular'),
#  (410375784, u'cafe', u'amenity', u'regular'),
#  (410798906, u'cafe', u'amenity', u'regular'),
#  (410801078, u'cafe', u'amenity', u'regular'),
#  (410953413, u'cafe', u'amenity', u'regular'),
#  (410986427, u'cafe', u'amenity', u'regular'),
#  (412330549, u'cafe', u'amenity', u'regular'),
#  (414574531, u'cafe', u'amenity', u'regular'),
#  (414574543, u'cafe', u'amenity', u'regular'),
#  (414610857, u'cafe', u'amenity', u'regular'),
#  (414941746, u'cafe', u'amenity', u'regular'),
#  (414945685, u'cafe', u'amenity', u'regular'),
#  (414966340, u'cafe', u'amenity', u'regular'),
#  (415208016, u'cafe', u'amenity', u'regular'),
#  (415843942, u'cafe', u'amenity', u'regular'),
#  (416731442, u'cafe', u'amenity', u'regular'),
#  (417231068, u'cafe', u'amenity', u'regular'),
#  (417231087, u'cafe', u'amenity', u'regular'),
#  (418868604, u'cafe', u'amenity', u'regular'),
#  (419357108, u'cafe', u'amenity', u'regular'),
#  (419372336, u'cafe', u'amenity', u'regular'),
#  (419372484, u'cafe', u'amenity', u'regular'),
#  (419380190, u'cafe', u'amenity', u'regular'),
#  (420464537, u'cafe', u'amenity', u'regular'),
#  (420542932, u'cafe', u'amenity', u'regular'),
#  (420549580, u'cafe', u'amenity', u'regular'),
#  (421904486, u'cafe', u'amenity', u'regular'),
#  (427687185, u'cafe', u'amenity', u'regular'),
#  (429659326, u'cafe', u'amenity', u'regular'),
#  (431143602, u'cafe', u'amenity', u'regular'),
#  (432773382, u'cafe', u'amenity', u'regular'),
#  (432777546, u'cafe', u'amenity', u'regular'),
#  (432777553, u'cafe', u'amenity', u'regular'),
#  (432780232, u'cafe', u'amenity', u'regular'),
#  (432783148, u'cafe', u'amenity', u'regular'),
#  (432784806, u'cafe', u'amenity', u'regular'),
#  (433542777, u'cafe', u'amenity', u'regular'),
#  (436015131, u'cafe', u'amenity', u'regular'),
#  (436886619, u'cafe', u'amenity', u'regular'),
#  (436893986, u'cafe', u'amenity', u'regular'),
#  (436904205, u'cafe', u'amenity', u'regular'),
#  (436926526, u'cafe', u'amenity', u'regular'),
#  (436950518, u'cafe', u'amenity', u'regular'),
#  (437988608, u'cafe', u'amenity', u'regular'),
#  (437992167, u'cafe', u'amenity', u'regular'),
#  (441031354, u'cafe', u'amenity', u'regular'),
#  (441477976, u'cafe', u'amenity', u'regular'),
#  (442125393, u'cafe', u'amenity', u'regular'),
#  (442126087, u'cafe', u'amenity', u'regular'),
#  (442126594, u'cafe', u'amenity', u'regular'),
#  (442127108, u'cafe', u'amenity', u'regular'),
#  (442134774, u'cafe', u'amenity', u'regular'),
#  (442134838, u'cafe', u'amenity', u'regular'),
#  (442754098, u'cafe', u'amenity', u'regular'),
#  (453882215, u'cafe', u'amenity', u'regular'),
#  (456201464, u'cafe', u'amenity', u'regular'),
#  (461587766, u'cafe', u'amenity', u'regular'),
#  (468239114, u'cafe', u'amenity', u'regular'),
#  (468327534, u'cafe', u'amenity', u'regular'),
#  (468417887, u'cafe', u'amenity', u'regular'),
#  (470063816, u'cafe', u'amenity', u'regular'),
#  (470069870, u'cafe', u'amenity', u'regular'),
#  (471562586, u'cafe', u'amenity', u'regular'),
#  (473507783, u'cafe', u'amenity', u'regular'),
#  (473507905, u'cafe', u'amenity', u'regular'),
#  (473533899, u'cafe', u'amenity', u'regular'),
#  (474956795, u'cafe', u'amenity', u'regular'),
#  (474958377, u'cafe', u'amenity', u'regular'),
#  (474960363, u'cafe', u'amenity', u'regular'),
#  (474965308, u'cafe', u'amenity', u'regular'),
#  (474967370, u'cafe', u'amenity', u'regular'),
#  (474968531, u'cafe', u'amenity', u'regular'),
#  (475881505, u'cafe', u'amenity', u'regular'),
#  (491599549, u'cafe', u'amenity', u'regular'),
#  (491800237, u'cafe', u'amenity', u'regular'),
#  (493881077, u'cafe', u'amenity', u'regular'),
#  (493881946, u'cafe', u'amenity', u'regular'),
#  (493882255, u'cafe', u'amenity', u'regular'),
#  (495306722, u'cafe', u'amenity', u'regular'),
#  (495306821, u'cafe', u'amenity', u'regular'),
#  (502049924, u'cafe', u'amenity', u'regular'),
#  (502783306, u'cafe', u'amenity', u'regular'),
#  (515553262, u'cafe', u'amenity', u'regular'),
#  (515618887, u'cafe', u'amenity', u'regular'),
#  (516605608, u'cafe', u'amenity', u'regular'),
#  (517226075, u'cafe', u'amenity', u'regular'),
#  (517226078, u'cafe', u'amenity', u'regular'),
#  (517226081, u'cafe', u'amenity', u'regular'),
#  (517227450, u'cafe', u'amenity', u'regular'),
#  (518259998, u'cafe', u'amenity', u'regular'),
#  (520007086, u'cafe', u'amenity', u'regular'),
#  (520007345, u'cafe', u'amenity', u'regular'),
#  (520017643, u'cafe', u'amenity', u'regular'),
#  (520060495, u'cafe', u'amenity', u'regular'),
#  (520390589, u'cafe', u'amenity', u'regular'),
#  (524113889, u'cafe', u'amenity', u'regular'),
#  (524114011, u'cafe', u'amenity', u'regular'),
#  (524114221, u'cafe', u'amenity', u'regular'),
#  (524114320, u'cafe', u'amenity', u'regular'),
#  (524141354, u'cafe', u'amenity', u'regular'),
#  (524150960, u'cafe', u'amenity', u'regular'),
#  (527025620, u'cafe', u'amenity', u'regular'),
#  (527025683, u'cafe', u'amenity', u'regular'),
#  (527025706, u'cafe', u'amenity', u'regular'),
#  (527229212, u'cafe', u'amenity', u'regular'),
#  (529523444, u'cafe', u'amenity', u'regular'),
#  (530715671, u'cafe', u'amenity', u'regular'),
#  (530775252, u'cafe', u'amenity', u'regular'),
#  (530783844, u'cafe', u'amenity', u'regular'),
#  (534354088, u'cafe', u'amenity', u'regular'),
#  (534370708, u'cafe', u'amenity', u'regular'),
#  (535026375, u'cafe', u'amenity', u'regular'),
#  (535031289, u'cafe', u'amenity', u'regular'),
#  (535036465, u'cafe', u'amenity', u'regular'),
#  (537074511, u'cafe', u'amenity', u'regular'),
#  (537074525, u'cafe', u'amenity', u'regular'),
#  (538151381, u'cafe', u'amenity', u'regular'),
#  (538151382, u'cafe', u'amenity', u'regular'),
#  (538159932, u'cafe', u'amenity', u'regular'),
#  (538159934, u'cafe', u'amenity', u'regular'),
#  (538343127, u'cafe', u'amenity', u'regular'),
#  (538343164, u'cafe', u'amenity', u'regular'),
#  (540244330, u'cafe', u'amenity', u'regular'),
#  (540294859, u'cafe', u'amenity', u'regular'),
#  (544554088, u'cafe', u'amenity', u'regular'),
#  (544664035, u'cafe', u'amenity', u'regular'),
#  (544664077, u'cafe', u'amenity', u'regular'),
#  (544664089, u'cafe', u'amenity', u'regular'),
#  (547496827, u'cafe', u'amenity', u'regular'),
#  (547531041, u'cafe', u'amenity', u'regular'),
#  (547664088, u'cafe', u'amenity', u'regular'),
#  (547724511, u'cafe', u'amenity', u'regular'),
#  (548982610, u'cafe', u'amenity', u'regular'),
#  (550881332, u'cafe', u'amenity', u'regular'),
#  (558657966, u'cafe', u'amenity', u'regular'),
#  (558790800, u'cafe', u'amenity', u'regular'),
#  (560227439, u'cafe', u'amenity', u'regular'),
#  (560227503, u'cafe', u'amenity', u'regular'),
#  (560634455, u'cafe', u'amenity', u'regular'),
#  (560634706, u'cafe', u'amenity', u'regular'),
#  (560635925, u'cafe', u'amenity', u'regular'),
#  (565571302, u'cafe', u'amenity', u'regular'),
#  (565586066, u'cafe', u'amenity', u'regular'),
#  (567253846, u'cafe', u'amenity', u'regular'),
#  (568177195, u'cafe', u'amenity', u'regular'),
#  (571545781, u'cafe', u'amenity', u'regular'),
#  (571545790, u'cafe', u'amenity', u'regular'),
#  (575209692, u'cafe', u'amenity', u'regular'),
#  (575245014, u'cafe', u'amenity', u'regular'),
#  (575254650, u'cafe', u'amenity', u'regular'),
#  (575626007, u'cafe', u'amenity', u'regular'),
#  (579244186, u'cafe', u'amenity', u'regular'),
#  (579253994, u'cafe', u'amenity', u'regular'),
#  (582746346, u'cafe', u'amenity', u'regular'),
#  (583007307, u'cafe', u'amenity', u'regular'),
#  (583013820, u'cafe', u'amenity', u'regular'),
#  (583868320, u'cafe', u'amenity', u'regular'),
#  (583868336, u'cafe', u'amenity', u'regular'),
#  (583868417, u'cafe', u'amenity', u'regular'),
#  (583868424, u'cafe', u'amenity', u'regular'),
#  (584718478, u'cafe', u'amenity', u'regular'),
#  (585467388, u'cafe', u'amenity', u'regular'),
#  (588338842, u'cafe', u'amenity', u'regular'),
#  (592835839, u'cafe', u'amenity', u'regular'),
#  (595418842, u'cafe', u'amenity', u'regular'),
#  (595418845, u'cafe', u'amenity', u'regular'),
#  (595418851, u'cafe', u'amenity', u'regular'),
#  (595418853, u'cafe', u'amenity', u'regular'),
#  (595418855, u'cafe', u'amenity', u'regular'),
#  (595495868, u'cafe', u'amenity', u'regular'),
#  (595495953, u'cafe', u'amenity', u'regular'),
#  (595496366, u'cafe', u'amenity', u'regular'),
#  (595986647, u'cafe', u'amenity', u'regular'),
#  (595987862, u'cafe', u'amenity', u'regular'),
#  (598101070, u'cafe', u'amenity', u'regular'),
#  (599896662, u'cafe', u'amenity', u'regular'),
#  (599896666, u'cafe', u'amenity', u'regular'),
#  (599897442, u'cafe', u'amenity', u'regular'),
#  (599897448, u'cafe', u'amenity', u'regular'),
#  (599897457, u'cafe', u'amenity', u'regular'),
#  (600252833, u'cafe', u'amenity', u'regular'),
#  (600645219, u'cafe', u'amenity', u'regular'),
#  (601602072, u'cafe', u'old_amenity', u'regular'),
#  (605209089, u'cafe', u'amenity', u'regular'),
#  (608753875, u'cafe', u'amenity', u'regular'),
#  (609279016, u'cafe', u'amenity', u'regular'),
#  (610978001, u'cafe', u'amenity', u'regular'),
#  (612012810, u'cafe', u'amenity', u'regular'),
#  (617329856, u'cafe', u'amenity', u'regular'),
#  (618122806, u'cafe', u'amenity', u'regular'),
#  (618124063, u'cafe', u'amenity', u'regular'),
#  (618749175, u'cafe', u'amenity', u'regular'),
#  (621417429, u'cafe', u'amenity', u'regular'),
#  (621426831, u'cafe', u'amenity', u'regular'),
#  (627775446, u'cafe', u'amenity', u'regular'),
#  (640959733, u'cafe', u'amenity', u'regular'),
#  (645621382, u'cafe', u'amenity', u'regular'),
#  (648766013, u'cafe', u'amenity', u'regular'),
#  (652153521, u'cafe', u'amenity', u'regular'),
#  (652164851, u'cafe', u'amenity', u'regular'),
#  (662721335, u'cafe', u'amenity', u'regular'),
#  (686704698, u'cafe', u'amenity', u'regular'),
#  (689654097, u'cafe', u'amenity', u'regular'),
#  (697805096, u'cafe', u'amenity', u'regular'),
#  (701670546, u'cafe', u'amenity', u'regular'),
#  (702516072, u'cafe', u'amenity', u'regular'),
#  (703115319, u'cafe', u'amenity', u'regular'),
#  (703690698, u'cafe', u'amenity', u'regular'),
#  (708861132, u'cafe', u'amenity', u'regular'),
#  (709877859, u'cafe', u'amenity', u'regular'),
#  (709877902, u'cafe', u'amenity', u'regular'),
#  (710732554, u'cafe', u'amenity', u'regular'),
#  (712613166, u'cafe', u'amenity', u'regular'),
#  (717893271, u'cafe', u'amenity', u'regular'),
#  (724851736, u'cafe', u'amenity', u'regular'),
#  (725883892, u'cafe', u'amenity', u'regular'),
#  (729417912, u'cafe', u'amenity', u'regular'),
#  (738174079, u'cafe', u'amenity', u'regular'),
#  (746028515, u'cafe', u'amenity', u'regular'),
#  (749980668, u'cafe', u'amenity', u'regular'),
#  (752192420, u'cafe', u'amenity', u'regular'),
#  (761870888, u'cafe', u'amenity', u'regular'),
#  (762599225, u'cafe', u'amenity', u'regular'),
#  (762599369, u'cafe', u'amenity', u'regular'),
#  (765377605, u'cafe', u'amenity', u'regular'),
#  (766943193, u'cafe', u'amenity', u'regular'),
#  (766943637, u'cafe', u'amenity', u'regular'),
#  (766954741, u'cafe', u'amenity', u'regular'),
#  (769503588, u'cafe', u'amenity', u'regular'),
#  (769509931, u'cafe', u'amenity', u'regular'),
#  (772058683, u'cafe', u'amenity', u'regular'),
#  (772366445, u'cafe', u'amenity', u'regular'),
#  (773490272, u'cafe', u'amenity', u'regular'),
#  (773498312, u'cafe', u'amenity', u'regular'),
#  (775895399, u'cafe', u'amenity', u'regular'),
#  (775896053, u'cafe', u'amenity', u'regular'),
#  (777804064, u'cafe', u'amenity', u'regular'),
#  (803152543, u'cafe', u'amenity', u'regular'),
#  (804332642, u'cafe', u'amenity', u'regular'),
#  (805136833, u'cafe', u'amenity', u'regular'),
#  (821376469, u'cafe', u'amenity', u'regular'),
#  (835013072, u'cafe', u'amenity', u'regular'),
#  (836345697, u'cafe', u'amenity', u'regular'),
#  (845505194, u'cafe', u'amenity', u'regular'),
#  (848258164, u'cafe', u'amenity', u'regular'),
#  (860764215, u'cafe', u'amenity', u'regular'),
#  (860789206, u'cafe', u'amenity', u'regular'),
#  (878279166, u'cafe', u'amenity', u'regular'),
#  (884354936, u'cafe', u'amenity', u'regular'),
#  (898454123, u'cafe', u'amenity', u'regular'),
#  (902313985, u'cafe', u'amenity', u'regular'),
#  (903729758, u'cafe', u'amenity', u'regular'),
#  (910381087, u'cafe', u'amenity', u'regular'),
#  (911226019, u'cafe', u'amenity', u'regular'),
#  (922168716, u'cafe', u'amenity', u'regular'),
#  (938000027, u'cafe', u'amenity', u'regular'),
#  (956092985, u'cafe', u'amenity', u'regular'),
#  (956093006, u'cafe', u'amenity', u'regular'),
#  (968464527, u'cafe', u'amenity', u'regular'),
#  (970668982, u'cafe', u'amenity', u'regular'),
#  (971471768, u'cafe', u'amenity', u'regular'),
#  (978057325, u'cafe', u'amenity', u'regular'),
#  (984715095, u'cafe', u'amenity', u'regular'),
#  (992128425, u'cafe', u'amenity', u'regular'),
#  (992134383, u'cafe', u'amenity', u'regular'),
#  (992352391, u'cafe', u'amenity', u'regular'),
#  (1064703152, u'cafe', u'amenity', u'regular'),
#  (1064713544, u'cafe', u'amenity', u'regular'),
#  (1071533939, u'cafe', u'amenity', u'regular'),
#  (1071862457, u'cafe', u'amenity', u'regular'),
#  (1080021856, u'cafe', u'amenity', u'regular'),
#  (1112701053, u'cafe', u'amenity', u'regular'),
#  (1113726655, u'cafe', u'amenity', u'regular'),
#  (1115945727, u'cafe', u'amenity', u'regular'),
#  (1115982071, u'cafe', u'amenity', u'regular'),
#  (1120722137, u'cafe', u'amenity', u'regular'),
#  (1122176091, u'cafe', u'amenity', u'regular'),
#  (1122911475, u'cafe', u'amenity', u'regular'),
#  (1123677272, u'cafe', u'amenity', u'regular'),
#  (1125188909, u'cafe', u'amenity', u'regular'),
#  (2246763619L, u'cafe', u'amenity', u'regular'),
#  (2253801842L, u'cafe', u'amenity', u'regular'),
#  (2253855509L, u'cafe', u'amenity', u'regular'),
#  (2269842481L, u'cafe', u'amenity', u'regular'),
#  (2270136402L, u'cafe', u'amenity', u'regular'),
#  (2271751956L, u'cafe', u'amenity', u'regular'),
#  (2273922901L, u'cafe', u'amenity', u'regular'),
#  (2274510227L, u'cafe', u'amenity', u'regular'),
#  (2286832897L, u'cafe', u'amenity', u'regular'),
#  (2288216727L, u'cafe', u'amenity', u'regular'),
#  (2288216729L, u'cafe', u'amenity', u'regular'),
#  (2288606546L, u'cafe', u'amenity', u'regular'),
#  (2290951790L, u'cafe', u'amenity', u'regular'),
#  (2290986322L, u'cafe', u'amenity', u'regular'),
#  (2291781324L, u'cafe', u'amenity', u'regular'),
#  (2294782947L, u'cafe', u'amenity', u'regular'),
#  (2295977867L, u'cafe', u'amenity', u'regular'),
#  (2295977874L, u'cafe', u'amenity', u'regular'),
#  (2296069358L, u'cafe', u'amenity', u'regular'),
#  (2297694928L, u'cafe', u'amenity', u'regular'),
#  (2301864546L, u'cafe', u'amenity', u'regular'),
#  (2303158968L, u'cafe', u'amenity', u'regular'),
#  (2304343045L, u'cafe', u'amenity', u'regular'),
#  (2304345473L, u'cafe', u'amenity', u'regular'),
#  (2309929541L, u'cafe', u'amenity', u'regular'),
#  (2313507300L, u'cafe', u'amenity', u'regular'),
#  (2333476280L, u'cafe', u'amenity', u'regular'),
#  (2342899751L, u'cafe', u'amenity', u'regular'),
#  (2344798367L, u'cafe', u'amenity', u'regular'),
#  (2346818597L, u'cafe', u'amenity', u'regular'),
#  (2349763737L, u'cafe', u'amenity', u'regular'),
#  (2349771831L, u'cafe', u'amenity', u'regular'),
#  (2349771835L, u'cafe', u'amenity', u'regular'),
#  (2358058324L, u'cafe', u'amenity', u'regular'),
#  (2363208444L, u'cafe', u'amenity', u'regular'),
#  (2365100289L, u'cafe', u'amenity', u'regular'),
#  (2365100290L, u'cafe', u'amenity', u'regular'),
#  (2374995802L, u'cafe', u'amenity', u'regular'),
#  (2374996786L, u'cafe', u'amenity', u'regular'),
#  (2383646448L, u'cafe', u'amenity', u'regular'),
#  (2388516176L, u'cafe', u'amenity', u'regular'),
#  (2392212245L, u'cafe', u'amenity', u'regular'),
#  (2392212248L, u'cafe', u'amenity', u'regular'),
#  (2394128560L, u'cafe', u'amenity', u'regular'),
#  (2395088259L, u'cafe', u'amenity', u'regular'),
#  (2405765136L, u'cafe', u'amenity', u'regular'),
#  (2405765138L, u'cafe', u'amenity', u'regular'),
#  (2405807641L, u'cafe', u'amenity', u'regular'),
#  (2405832055L, u'cafe', u'amenity', u'regular'),
#  (2405832059L, u'cafe', u'amenity', u'regular'),
#  (2405832062L, u'cafe', u'amenity', u'regular'),
#  (2410395449L, u'cafe', u'amenity', u'regular'),
#  (2413644928L, u'cafe', u'amenity', u'regular'),
#  (2415150109L, u'cafe', u'amenity', u'regular'),
#  (2719390655L, u'cafe', u'amenity', u'regular'),
#  (2721219352L, u'cafe', u'amenity', u'regular'),
#  (2725504901L, u'cafe', u'amenity', u'regular'),
#  (2731610686L, u'cafe', u'amenity', u'regular'),
#  (2731733037L, u'cafe', u'amenity', u'regular'),
#  (2738676296L, u'cafe', u'amenity', u'regular'),
#  (2738686605L, u'cafe', u'amenity', u'regular'),
#  (2752955078L, u'cafe', u'amenity', u'regular'),
#  (2753022198L, u'cafe', u'amenity', u'regular'),
#  (2753034348L, u'cafe', u'amenity', u'regular'),
#  (2753799487L, u'cafe', u'amenity', u'regular'),
#  (2760748946L, u'cafe', u'amenity', u'regular'),
#  (2764622666L, u'cafe', u'amenity', u'regular'),
#  (2765828402L, u'cafe', u'amenity', u'regular'),
#  (2765851406L, u'cafe', u'amenity', u'regular'),
#  (2767081787L, u'cafe', u'amenity', u'regular'),
#  (2767193246L, u'cafe', u'amenity', u'regular'),
#  (2767280140L, u'cafe', u'amenity', u'regular'),
#  (2770561750L, u'cafe', u'amenity', u'regular'),
#  (2780593062L, u'cafe', u'amenity', u'regular'),
#  (2780593064L, u'cafe', u'amenity', u'regular'),
#  (2783830651L, u'cafe', u'amenity', u'regular'),
#  (2788594444L, u'cafe', u'amenity', u'regular'),
#  (2790612868L, u'cafe', u'amenity', u'regular'),
#  (2795566335L, u'cafe', u'amenity', u'regular'),
#  (2796795669L, u'cafe', u'amenity', u'regular'),
# ...
#  (3097449507L, u'cafe', u'amenity', u'regular'),
#  (3098092823L, u'cafe', u'amenity', u'regular'),
#  (3099478482L, u'cafe', u'amenity', u'regular'),
#  (3099830650L, u'cafe', u'amenity', u'regular'),
#  (3116793901L, u'cafe', u'amenity', u'regular'),
#  (3119029284L, u'cafe', u'amenity', u'regular'),
#  (3119032737L, u'cafe', u'amenity', u'regular'),
#  (3119035625L, u'cafe', u'amenity', u'regular'),
#  (3124476381L, u'cafe', u'amenity', u'regular'),
#  (3159506029L, u'cafe', u'amenity', u'regular'),
#  (3175006642L, u'cafe', u'amenity', u'regular'),
#  (3192602820L, u'cafe', u'amenity', u'regular'),
#  (3206970910L, u'cafe', u'amenity', u'regular'),
#  (3206983509L, u'cafe', u'amenity', u'regular'),
#  (3210493889L, u'cafe', u'amenity', u'regular'),
#  (3212853792L, u'cafe', u'amenity', u'regular'),
#  (3213412801L, u'cafe', u'amenity', u'regular'),
#  (3216526043L, u'cafe', u'amenity', u'regular'),
#  (3229198861L, u'cafe', u'amenity', u'regular'),
#  (3229203077L, u'cafe', u'amenity', u'regular'),
#  (3229203810L, u'cafe', u'amenity', u'regular'),
#  (3229210091L, u'cafe', u'amenity', u'regular'),
#  (3231903525L, u'cafe', u'amenity', u'regular'),
#  (3237108610L, u'cafe', u'amenity', u'regular'),
#  (3245342256L, u'cafe', u'amenity', u'regular'),
#  (3247754010L, u'cafe', u'amenity', u'regular'),
#  (3265539433L, u'cafe', u'amenity', u'regular'),
#  (3269861137L, u'cafe', u'amenity', u'regular'),
#  (3281354332L, u'cafe', u'amenity', u'regular'),
#  (3288813686L, u'cafe', u'amenity', u'regular'),
#  (3297272223L, u'cafe', u'amenity', u'regular'),
#  (3301702815L, u'cafe', u'amenity', u'regular'),
#  (3301710267L, u'cafe', u'amenity', u'regular'),
#  (3301817982L, u'cafe', u'amenity', u'regular'),
#  (3303274928L, u'cafe', u'amenity', u'regular'),
#  (3306467139L, u'cafe', u'amenity', u'regular'),
#  (3306493402L, u'cafe', u'amenity', u'regular'),
#  (3308637280L, u'cafe', u'amenity', u'regular'),
#  (3311074966L, u'cafe', u'amenity', u'regular'),
#  (3314874485L, u'cafe', u'amenity', u'regular'),
#  (3315345849L, u'cafe', u'amenity', u'regular'),
#  (3316942378L, u'cafe', u'amenity', u'regular'),
#  (3317175461L, u'cafe', u'amenity', u'regular'),
#  (3317181966L, u'cafe', u'amenity', u'regular'),
#  (3320195207L, u'cafe', u'amenity', u'regular'),
#  (3321027858L, u'cafe', u'amenity', u'regular'),
#  (3329263291L, u'cafe', u'amenity', u'regular'),
#  (3333046455L, u'cafe', u'amenity', u'regular'),
#  (3338997896L, u'cafe', u'amenity', u'regular'),
#  (3346660452L, u'cafe', u'amenity', u'regular'),
#  (3354817859L, u'cafe', u'amenity', u'regular'),
#  (3364854941L, u'cafe', u'amenity', u'regular'),
#  (3370258900L, u'cafe', u'amenity', u'regular'),
#  (3380246866L, u'cafe', u'amenity', u'regular'),
#  (3380252542L, u'cafe', u'amenity', u'regular'),
#  (3391253124L, u'cafe', u'amenity', u'regular'),
#  (3409474825L, u'cafe', u'amenity', u'regular'),
#  (3410784119L, u'cafe', u'amenity', u'regular'),
#  (3418915696L, u'cafe', u'amenity', u'regular'),
#  (3424111593L, u'cafe', u'amenity', u'regular'),
#  (3426157172L, u'cafe', u'amenity', u'regular'),
#  (3427096413L, u'cafe', u'amenity', u'regular'),
#  (3427252955L, u'cafe', u'amenity', u'regular'),
#  (3427256945L, u'cafe', u'amenity', u'regular'),
#  (3427697071L, u'cafe', u'amenity', u'regular'),
#  (3430046171L, u'cafe', u'amenity', u'regular'),
#  (3439310962L, u'cafe', u'amenity', u'regular'),
#  (3439310963L, u'cafe', u'amenity', u'regular'),
#  (3440964207L, u'cafe', u'amenity', u'regular'),
#  (3445763481L, u'cafe', u'amenity', u'regular'),
#  (3452961426L, u'cafe', u'amenity', u'regular'),
#  (3455030545L, u'cafe', u'amenity', u'regular'),
#  (3458153763L, u'cafe', u'amenity', u'regular'),
#  (3460612821L, u'cafe', u'amenity', u'regular'),
#  (3463657262L, u'cafe', u'amenity', u'regular'),
#  (3464500066L, u'cafe', u'amenity', u'regular'),
#  (3464734483L, u'cafe', u'amenity', u'regular'),
#  (3466933901L, u'cafe', u'amenity', u'regular'),
#  (3466958611L, u'cafe', u'amenity', u'regular'),
#  (3467065129L, u'cafe', u'amenity', u'regular'),
#  (3468396705L, u'cafe', u'amenity', u'regular'),
#  (3468561288L, u'cafe', u'amenity', u'regular'),
#  (3468671557L, u'cafe', u'amenity', u'regular'),
#  (3473921145L, u'cafe', u'amenity', u'regular'),
#  (3474264108L, u'cafe', u'amenity', u'regular'),
#  (3476578583L, u'cafe', u'amenity', u'regular'),
#  (3476623851L, u'cafe', u'amenity', u'regular'),
#  (3477630779L, u'cafe', u'amenity', u'regular'),
#  (3477658898L, u'cafe', u'amenity', u'regular'),
#  (3477658901L, u'cafe', u'amenity', u'regular'),
#  (3480403697L, u'cafe', u'amenity', u'regular'),
#  (3482078776L, u'cafe', u'amenity', u'regular'),
#  (3482106447L, u'cafe', u'amenity', u'regular'),
#  (3484654271L, u'cafe', u'amenity', u'regular'),
#  (3487819409L, u'cafe', u'amenity', u'regular'),
#  (3489946293L, u'cafe', u'amenity', u'regular'),
#  (3491954972L, u'cafe', u'amenity', u'regular'),
#  (3507050678L, u'cafe', u'amenity', u'regular'),
#  (3548361877L, u'cafe', u'amenity', u'regular'),
#  (3556589512L, u'cafe', u'amenity', u'regular'),
#  (3559442059L, u'cafe', u'amenity', u'regular'),
#  (3561284969L, u'cafe', u'amenity', u'regular'),
#  (3561594873L, u'cafe', u'amenity', u'regular'),
#  (3562034670L, u'cafe', u'amenity', u'regular'),
#  (3562198326L, u'cafe', u'amenity', u'regular'),
#  (3562256910L, u'cafe', u'amenity', u'regular'),
#  (3572166952L, u'cafe', u'amenity', u'regular'),
#  (3584042465L, u'cafe', u'amenity', u'regular'),
#  (3584546817L, u'cafe', u'amenity', u'regular'),
#  (3584692560L, u'cafe', u'amenity', u'regular'),
#  (3586994485L, u'cafe', u'amenity', u'regular'),
#  (3587014147L, u'cafe', u'amenity', u'regular'),
#  (3587014148L, u'cafe', u'amenity', u'regular'),
#  (3595537293L, u'cafe', u'amenity', u'regular'),
#  (3597533181L, u'cafe', u'amenity', u'regular'),
#  (3599545630L, u'cafe', u'amenity', u'regular'),
#  (3600949039L, u'cafe', u'amenity', u'regular'),
#  (3602419558L, u'cafe', u'amenity', u'regular'),
#  (3620991484L, u'cafe', u'amenity', u'regular'),
#  (3620992884L, u'cafe', u'amenity', u'regular'),
#  (3623552885L, u'cafe', u'amenity', u'regular'),
#  (3635875046L, u'cafe', u'amenity', u'regular'),
#  (3639905312L, u'cafe', u'amenity', u'regular'),
#  (3641029235L, u'cafe', u'amenity', u'regular'),
#  (3643360967L, u'cafe', u'amenity', u'regular'),
#  (3650952104L, u'cafe', u'amenity', u'regular'),
#  (3664711503L, u'cafe', u'amenity', u'regular'),
#  (3665419217L, u'cafe', u'amenity', u'regular'),
#  (3668839194L, u'cafe', u'amenity', u'regular'),
#  (3672015337L, u'cafe', u'amenity', u'regular'),
#  (3687539999L, u'cafe', u'amenity', u'regular'),
#  (3691998589L, u'cafe', u'amenity', u'regular'),
#  (3696230524L, u'cafe', u'amenity', u'regular'),
#  (3697979358L, u'cafe', u'amenity', u'regular'),
#  (3698533566L, u'cafe', u'amenity', u'regular'),
#  (3700398413L, u'cafe', u'amenity', u'regular'),
#  (3904977244L, u'cafe', u'amenity', u'regular'),
#  (3905865029L, u'cafe', u'amenity', u'regular'),
#  (3908516143L, u'cafe', u'amenity', u'regular'),
#  (3919855497L, u'cafe', u'amenity', u'regular'),
#  (3924709142L, u'cafe', u'amenity', u'regular'),
#  (3925813291L, u'cafe', u'amenity', u'regular'),
#  (3928028041L, u'cafe', u'amenity', u'regular'),
#  (3930426863L, u'cafe', u'amenity', u'regular'),
#  (3931418544L, u'cafe', u'amenity', u'regular'),
#  (3932411793L, u'cafe', u'amenity', u'regular'),
#  (3932550871L, u'cafe', u'amenity', u'regular'),
#  (3933103721L, u'cafe', u'amenity', u'regular'),
#  (3934168825L, u'cafe', u'amenity', u'regular'),
#  (3939878203L, u'cafe', u'amenity', u'regular'),
#  (3957196268L, u'cafe', u'amenity', u'regular'),
#  (3959776422L, u'cafe', u'amenity', u'regular'),
#  (3959870360L, u'cafe', u'amenity', u'regular'),
#  (3969619092L, u'cafe', u'amenity', u'regular'),
#  (3969700263L, u'cafe', u'amenity', u'regular'),
#  (3975023789L, u'cafe', u'amenity', u'regular'),
#  (3975023790L, u'cafe', u'amenity', u'regular'),
#  (3976539735L, u'cafe', u'amenity', u'regular'),
#  (3982864750L, u'cafe', u'amenity', u'regular'),
#  (3985385465L, u'cafe', u'amenity', u'regular'),
#  (3985385544L, u'cafe', u'amenity', u'regular'),
#  (3989280861L, u'cafe', u'amenity', u'regular'),
#  (3989280864L, u'cafe', u'amenity', u'regular'),
#  (3997648559L, u'cafe', u'amenity', u'regular'),
#  (3997648561L, u'cafe', u'amenity', u'regular'),
#  (4001010034L, u'cafe', u'amenity', u'regular'),
#  (4004435213L, u'cafe', u'amenity', u'regular'),
#  (4012000352L, u'cafe', u'amenity', u'regular'),
#  (4012033013L, u'cafe', u'amenity', u'regular'),
#  (4013650573L, u'cafe', u'amenity', u'regular'),
#  (4013827091L, u'cafe', u'amenity', u'regular'),
#  (4014895306L, u'cafe', u'amenity', u'regular'),
#  (4015333400L, u'cafe', u'amenity', u'regular'),
#  (4015486047L, u'cafe', u'amenity', u'regular'),
#  (4015549355L, u'cafe', u'amenity', u'regular'),
#  (4015586069L, u'cafe', u'amenity', u'regular'),
#  (4015590236L, u'cafe', u'amenity', u'regular'),
#  (4015804201L, u'cafe', u'amenity', u'regular'),
#  (4017888663L, u'cafe', u'amenity', u'regular'),
#  (4018065437L, u'cafe', u'amenity', u'regular'),
#  (4029689127L, u'cafe', u'amenity', u'regular'),
#  (4030020002L, u'cafe', u'amenity', u'regular'),
#  (4030189880L, u'cafe', u'amenity', u'regular'),
#  (4030369265L, u'cafe', u'amenity', u'regular'),
#  (4030414326L, u'cafe', u'amenity', u'regular'),
#  (4044936635L, u'cafe', u'amenity', u'regular'),
#  (4047007530L, u'cafe', u'amenity', u'regular'),
#  (4048603030L, u'cafe', u'amenity', u'regular'),
#  (4055830330L, u'cafe', u'amenity', u'regular'),
#  (4058404693L, u'cafe', u'amenity', u'regular'),
#  (4352737693L, u'cafe', u'amenity', u'regular'),
#  (4353363377L, u'cafe', u'amenity', u'regular'),
#  (4358881074L, u'cafe', u'amenity', u'regular'),
#  (4358910938L, u'cafe', u'amenity', u'regular'),
#  (4359488194L, u'cafe', u'amenity', u'regular'),
#  (4360322838L, u'cafe', u'amenity', u'regular'),
#  (4363270693L, u'cafe', u'amenity', u'regular'),
#  (4366104636L, u'cafe', u'amenity', u'regular'),
#  (4366610594L, u'cafe', u'amenity', u'regular'),
#  (4368589695L, u'cafe', u'amenity', u'regular'),
#  (4368797988L, u'cafe', u'amenity', u'regular'),
#  (4368798489L, u'cafe', u'amenity', u'regular'),
#  (4373035917L, u'cafe', u'amenity', u'regular'),
#  (4373035919L, u'cafe', u'amenity', u'regular'),
#  (4373035921L, u'cafe', u'amenity', u'regular'),
#  (4373036386L, u'cafe', u'amenity', u'regular'),
#  (4376701848L, u'cafe', u'amenity', u'regular'),
#  (4379364905L, u'cafe', u'amenity', u'regular'),
#  (4398348042L, u'cafe', u'amenity', u'regular'),
#  (4405581395L, u'cafe', u'amenity', u'regular'),
#  (4410798124L, u'cafe', u'amenity', u'regular'),
#  (4412251891L, u'cafe', u'amenity', u'regular'),
#  (4413390809L, u'cafe', u'amenity', u'regular'),
#  (4413611189L, u'cafe', u'amenity', u'regular'),
#  (4414960588L, u'cafe', u'amenity', u'regular'),
#  (4415114188L, u'cafe', u'amenity', u'regular'),
#  (4418292392L, u'cafe', u'amenity', u'regular')]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT STRFTIME('%Y', timestamp) as year, COUNT(*)
    FROM nodes
    GROUP BY year
    ORDER BY year DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'2016', 379884),
#  (u'2015', 320166),
#  (u'2014', 456962),
#  (u'2013', 394806),
#  (u'2012', 769813),
#  (u'2011', 598622),
#  (u'2010', 1444220),
#  (u'2009', 438753),
#  (u'2008', 52188),
#  (u'2007', 17162),
#  (u'2006', 774)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT STRFTIME('%Y', timestamp) as year, COUNT(*)
    FROM ways
    GROUP BY year
    ORDER BY year DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'2016', 107786),
#  (u'2015', 90670),
#  (u'2014', 68349),
#  (u'2013', 75598),
#  (u'2012', 65214),
#  (u'2011', 87542),
#  (u'2010', 190070),
#  (u'2009', 24653),
#  (u'2008', 923),
#  (u'2007', 138),
#  (u'2006', 1)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Number of ways and nodes added to the database each year 
c.execute ('''
    SELECT STRFTIME('%Y', timestamp) as year, COUNT(*)
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways)
    GROUP BY year
    ORDER BY year DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'2016', 52011),
#  (u'2015', 57476),
#  (u'2014', 52523),
#  (u'2013', 52881),
#  (u'2012', 144792),
#  (u'2011', 99937),
#  (u'2010', 241083),
#  (u'2009', 114439),
#  (u'2008', 17638),
#  (u'2007', 4653),
#  (u'2006', 372)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Which months of which years had the most ways and nodes added to the database
c.execute ('''
    SELECT STRFTIME('%Y-%m', timestamp) as yearMonth, COUNT(*)
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways)
    GROUP BY yearMonth
    ORDER BY COUNT(*) DESC
    LIMIT 5
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'2010-09', 75669),
#  (u'2010-04', 59329),
#  (u'2010-07', 58310),
#  (u'2012-04', 33734),
#  (u'2012-05', 29342)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# Which year-month had the highest amount of node/way entries
c.execute ('''
    SELECT STRFTIME('%Y-%m', timestamp) as yearMonth
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways)
    GROUP BY yearMonth
    ORDER BY COUNT(*) DESC
    LIMIT 1
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'2010-09',)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# How many node or way tags were created in the year-month with the highest amount of entries
c.execute ('''
    SELECT COUNT(*)
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways),
    (SELECT STRFTIME('%Y-%m', timestamp) as yearMonth
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways)
    GROUP BY yearMonth
    ORDER BY COUNT(*) DESC
    LIMIT 1) as subq
    WHERE STRFTIME('%Y-%m', timestamp) = yearMonth
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(75669,)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
# In the year-month with the highest way/node entries, which users were adding to the database and how many
# entries did each user contribute
c.execute ('''
    SELECT user, COUNT(*)
    FROM (SELECT timestamp, user FROM nodes
    UNION SELECT timestamp, user FROM ways),
    (SELECT STRFTIME('%Y-%m', timestamp) as yearMonth
    FROM (SELECT timestamp FROM nodes
    UNION SELECT timestamp FROM ways)
    GROUP BY yearMonth
    ORDER BY COUNT(*) DESC
    LIMIT 1) as subq
    WHERE STRFTIME('%Y-%m', timestamp) = yearMonth
    GROUP BY user
    ORDER BY COUNT(*) DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'andrewpmk', 72535),
#  (u'Victor Bielawski', 2949),
#  (u'bdustan', 101),
#  (u'mfagan', 25),
#  (u'MikeyCarter', 23),
#  (u'tixuwuoz', 18),
#  (u'bgibbard', 13),
#  (u'brandoncote', 10),
#  (u'salocinbake', 8),
#  (u'emvee', 7),
#  (u'Andre68', 2),
#  (u'Sven L', 1),
#  (u'de239', 1)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT user, COUNT(*)
    FROM (SELECT timestamp, user FROM nodes
    UNION SELECT timestamp, user FROM ways)
    WHERE STRFTIME('%Y-%m', timestamp) = '2010-09'
    GROUP BY user
    ORDER BY COUNT(*) DESC
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'andrewpmk', 72535),
#  (u'Victor Bielawski', 2949),
#  (u'bdustan', 101),
#  (u'mfagan', 25),
#  (u'MikeyCarter', 23),
#  (u'tixuwuoz', 18),
#  (u'bgibbard', 13),
#  (u'brandoncote', 10),
#  (u'salocinbake', 8),
#  (u'emvee', 7),
#  (u'Andre68', 2),
#  (u'Sven L', 1),
#  (u'de239', 1)]

# %%
db = sqlite3.connect(sqlite_file)
c = db.cursor()
c.execute ('''
    SELECT user, COUNT(*)
    FROM (SELECT timestamp, user FROM nodes
    UNION SELECT timestamp, user FROM ways)
    GROUP BY user
    ORDER BY COUNT(*) DESC
    LIMIT 5
    ''')
all_rows = c.fetchall()
pprint(all_rows)
db.close()
# Out:
# [(u'andrewpmk', 533475),
#  (u'MikeyCarter', 64494),
#  (u'Victor Bielawski', 40151),
#  (u'rw__', 28356),
#  (u'Kevo', 25771)]
